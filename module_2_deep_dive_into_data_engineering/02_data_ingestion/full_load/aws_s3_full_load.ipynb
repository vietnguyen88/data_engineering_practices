# %%
import boto3
import awswrangler as wr
from dotenv import load_dotenv
import os

load_dotenv()

# Credentials
aws_access_key_id = os.getenv('aws_access_key_id')
aws_secret_access_key = os.getenv('aws_secret_access_key')

# S3 Location
S3_BUCKET = 'cm-aws-s3-data-source'
S3_FOLDER_PATH = 'organization/sales'

# create a authorized session using boto3 + credentials
session = boto3.Session(
    aws_access_key_id=aws_access_key_id,
    aws_secret_access_key=aws_secret_access_key,
)
# create s3 client to interact with AWS S3
s3 = session.client(service_name='s3')

# %% [markdown]
# Full Load - Snapshot

# %%
# HINTS
bucket_name = 'cm-aws-s3-data-source'
download_path = 'destination/sales/snapshot' 
os.makedirs(download_path,exist_ok=True)

# 1. list_objects_v2 >> List all objects
res = s3.list_objects_v2(Bucket ='cm-aws-s3-data-source',Prefix='organization/sales')

# 2. download_file >> download file
# loop through objects and exlcude first object
for obj in res['Contents'][1:]:
    obj_name_path = obj['Key']
    file_name = obj['Key'][19:]
    # key is directory of files, file name is new location of downloaded files
    s3.download_file(Bucket=bucket_name,Key=obj_name_path,Filename=f'{download_path}/{file_name}')

# 3. Download all files to "destination/sales/snapshot"

# %% [markdown]
# Full Load - Partition by Ingestion Date

# %%
# HINTS
# 1. list_objects_v2 >> List all objects
# 2. download_file >> download file
# 3. Download all files to "destination/sales/<ingestion_date>"
